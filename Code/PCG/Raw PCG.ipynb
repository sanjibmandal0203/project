# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat

# %% [markdown]
# # Mat file

# %%
data=loadmat(r"D:/JN/data set/data from web/PCG_1000hz_aug/a0001_0.mat")

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'val'])

# %%
df=pd.DataFrame(data['val'])

# %%
df
# Out:
#              0             1         2             3
# 0     0.480846  5.073115e-08  0.000006  5.966059e-07
# 1     0.406669  8.999133e-03  0.076095  7.631776e-02
# 2     0.331736  1.592333e-02  0.108962 -6.139788e-02
# 3     0.255358  1.932308e-02  0.087406  2.292093e-03
# 4     0.176980  1.881382e-02  0.034657  2.195131e-02
# ...        ...           ...       ...           ...
# 7995  1.046066  2.635377e-02  0.066393  8.654005e-03
# 7996  0.967279  2.981853e-02  0.011230 -2.284660e-02
# 7997  0.880083  3.005288e-02 -0.047625  6.872534e-03
# 7998  0.786568  2.591849e-02 -0.073881  1.893727e-02
# 7999  0.688825  1.685634e-02 -0.057513  1.234729e-03
#
# [8000 rows x 4 columns]

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size for better visibility
plt.plot(df)  # Plot all columns of the DataFrame
plt.title("Visualization of DataFrame 'df'")
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend(df.columns, loc='upper right')  # Add a legend for column identification
plt.grid(True)  # Add a grid for better readability
plt.show()  # Display the plot

# %% [markdown]
# first column

# %%
plt.figure(figsize=(12, 4))  # Adjust figure size for better visibility
plt.plot(df[0].values)  # Plot all columns of the DataFrame
plt.title("Visualization of the First column of DataFrame 'df' (a0001_0.csv)")
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend(df.columns, loc='upper right')  # Add a legend for column identification
plt.grid(True)  # Add a grid for better readability
plt.show()  # Display the plot

# %% [raw]
# second column

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size for better visibility
plt.plot(df[1].values)  # Plot all columns of the DataFrame
plt.title("Visualization of the second column of DataFrame 'df' (a0001_0.csv)")
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend(df.columns, loc='upper right')  # Add a legend for column identification
plt.grid(True)  # Add a grid for better readability
plt.show()  # Display the plot

# %% [raw]
# Third column

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size for better visibility
plt.plot(df[2].values)  # Plot all columns of the DataFrame
plt.title("Visualization of the third column of DataFrame 'df' (a0001_0.csv)")
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend(df.columns, loc='upper right')  # Add a legend for column identification
plt.grid(True)  # Add a grid for better readability
plt.show()  # Display the plot

# %% [raw]
# Forth column

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size for better visibility
plt.plot(df[3].values)  # Plot all columns of the DataFrame
plt.title("Visualization of the third column of DataFrame 'df' (a0001_0.csv)")
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend(df.columns, loc='upper right')  # Add a legend for column identification
plt.grid(True)  # Add a grid for better readability
plt.show()  # Display the plot
